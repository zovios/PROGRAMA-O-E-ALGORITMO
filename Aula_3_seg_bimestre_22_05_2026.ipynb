# %% [markdown]
# <a href="https://colab.research.google.com/github/zovios/PROGRAMA-O-E-ALGORITMO/blob/main/Aula_3_seg_bimestre_22_05_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Calculadora com 4 operações
#Op1 - somar
#Op2 - subtrair
#Op3 -multiplicar
#Op4 -divisão
#Op5 - sair
opcao= 0
a= 0
b= 0

print( "~" * 20)
print("Op1 - somar")
print("Op2 - subtrair")
print("Op3 -multiplicar")
print("Op4 -divisão")
print("Op5 - sair")
print( "~" * 20)
  print("Opção não disponível")
  while opcao != 5:
    opcao= int(input("Digite uma opção de 1 a 4 ou 5 para sair: "))
    if opcao == 1:

      a= int(input("Digite o número : "))
      b= int(input("Digite o número : "))
      print(f"Total da soma = {a + b}")

    elif opcao ==2:

      a=int(input("Digite o número : "))
      b=int(input("Digite o número : "))
      print(f"Total da subtração = {a-b}")

    elif opcao ==3:

      a=int(input("Digite o número : "))
      b=int(input("Digite o número : "))
      print(f"Total da multiplição = {a*b}")

    elif opcao ==4:

      a=int(input("Digite o número : "))
      b=int(input("Digite o número : "))
      print(f"Total da divisão = {a/b}")

    elif opcao ==5:
      break
    else:
      print("Opção não disponível")
# Out:
#   File "/tmp/ipykernel_8352/3547810714.py", line 18
#     print("Opção não disponível")
#     ^
# IndentationError: unexpected indent

# %%
# escrever um programa que recebe as notas do aluno referente aos 4 bimestres.

# calcular a média das notas e imprimir a mensagem de aprovado, recuperação ou reprovado

#nota maior ou igual a 7, aprovado.
#nota maior ou igual a 5, recuperação
#nota menor que 5, reprovado

nota1 = int(input("digite sua nota aqui"))
nota2 = int(input("digite sua nota aqui"))
nota3 = int(input("digite sua nota aqui"))
nota4 = int(input("digite sua nota aqui"))
média = (nota1 + nota2 + nota3 + nota4) / 4
